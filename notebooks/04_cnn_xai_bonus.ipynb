# %% [markdown]
# # 04 - Bonus XAI
#
# Este notebook mostra uma extensao avancada leve: permutation importance aplicada ao Random Forest. A parte obrigatoria do projeto esta nos notebooks 01 a 03.

# %%
from pathlib import Path
import os
import sys

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)

Path.cwd()

# %%
!"{sys.executable}" scripts/explain_model.py --model outputs/modelos/random_forest.joblib --split test --top 20

# %% [markdown]
# A figura em `outputs/xai/permutation_importance.png` mostra quais features mais afetam o F1 macro quando seus valores sao embaralhados. Se features de cor e textura aparecerem no topo, isso reforca uma explicacao coerente para frutas podres.
