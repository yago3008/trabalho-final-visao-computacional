# %% [markdown]
# # 01 - Segmentacao
#
# Objetivo: preparar uma amostra balanceada e comparar dois metodos classicos de isolamento da fruta: HSV e Otsu.

# %%
from pathlib import Path
import os
import sys

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)

Path.cwd()

# %%
!"{sys.executable}" scripts/prepare_dataset.py --train-per-class 500 --test-per-class 150

# %%
!"{sys.executable}" scripts/run_segmentation_examples.py --per-class 5

# %% [markdown]
# As figuras geradas em `outputs/figuras/segmentacao` devem ser usadas para discutir acertos, falhas e a escolha do metodo de segmentacao.
