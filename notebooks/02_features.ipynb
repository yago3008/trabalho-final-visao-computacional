# %% [markdown]
# # 02 - Features
#
# Objetivo: extrair features manuais de forma, momentos de Hu, cor e textura.

# %%
from pathlib import Path
import os
import sys

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)

Path.cwd()

# %%
!"{sys.executable}" scripts/run_features.py --segmentation hsv --size 256

# %%
!"{sys.executable}" scripts/analyze_features.py --k 12

# %% [markdown]
# Saidas esperadas: `X.csv`, `y.csv`, boxplots, PCA, matriz de correlacao e ranking SelectKBest.
