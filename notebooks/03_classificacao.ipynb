# %% [markdown]
# # 03 - Classificacao
#
# Objetivo: treinar e comparar Regressao Logistica, SVM e Random Forest usando a tabela de features manuais.

# %%
from pathlib import Path
import os
import sys

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)

Path.cwd()

# %%
!"{sys.executable}" scripts/train_models.py

# %%
!"{sys.executable}" scripts/copy_error_examples.py --errors outputs/modelos/random_forest_test_errors.csv --out outputs/erros/random_forest --limit 10

# %% [markdown]
# Use `outputs/modelos/metricas_modelos.csv`, matrizes de confusao e imagens em `outputs/erros` para discutir o melhor modelo e as limitacoes.
